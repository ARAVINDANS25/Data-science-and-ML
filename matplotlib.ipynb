# %%
import matplotlib.pyplot as plt
import numpy as np
Xpoint=np.array([0,8])
Ypoint=np.array([5,50])
plt.plot(Xpoint,Ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
point=np.array([1,3,5,7,9])
plt.plot(ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([1,8,5,9])
ypoint=np.array([3,6,30,50])
plt.plot(xpoint,ypoint)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint=np.array([1,5])
ypoint=np.array([5,9])
plt.plot(xpoint,ypoint,"o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,marker='H')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9,6,7])
plt.plot(ypoint,marker='H')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,"--",marker='s')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,marker='*',ms=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,marker='s',ms=20,mec="red",mfc="black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,marker='s',ms=20,mec="r",mfc="black")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,marker='s',ms=20,mec="red",mfc="#ffcc00",color="y")
plt.show()

# %% [markdown]
# line style

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,":",marker='s',ms=20,mec="red",mfc="#ffcc00",color="y")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,linestyle="solid")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,color="gray")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint=np.array([5,9])
plt.plot(ypoint,linewidth="10.5")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1point=np.array([1,2,8,9,10])
y2point=np.array([3,4,5,6,7])
plt.plot(y1point,":",marker='s',color="black")
plt.plot(y2point,":",marker='H',color="green")
plt.show()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([1,2,8,9,10])
y2=np.array([3,4,5,6,7])
x2=np.array([3,4,5,6,7])
y2=np.array([1,2,8,9,10])
plt.plot(x1,y1,x2,y2)
plt.show()

# %% [markdown]
# label

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,89,87,85,84,82])
y=np.array([90,230,280,246,166,256])
plt.plot(x,y)
plt.xlabel("average pulse")
plt.ylabel("cal")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,89,87,85,84,82])
y=np.array([90,230,280,246,166,256])
plt.title("sport")
plt.plot(x,color="green")
plt.plot(y,color="red")
plt.xlabel("average pulse")
plt.ylabel("cal")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,89,87,85,84,82])
y=np.array([90,230,280,246,166,256])
plt.title("sport",loc="left")
plt.plot(x,color="green")
plt.plot(y,color="red")
plt.xlabel("average pulse",loc="left")
plt.ylabel("cal",loc="top")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,89,87,85,84,82])
y=np.array([90,230,280,246,166,256])
plt.title("sport")
plt.xlabel("average pulse")
plt.ylabel("cal")
plt.plot(x,label="veg",color="green")
plt.plot(y,label="fru",color="red")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,89,87,85,84,82])
y=np.array([90,230,280,246,166,256])
plt.title("sport")
plt.xlabel("average pulse")
plt.ylabel("cal")
plt.plot(x,label="veg",color="green")
plt.plot(y,label="fru",color="red")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,90,86,84,83])
y=np.array([120,130,125,134,150])
plt.title("sport watch data")
plt.xlabel("average pulse")
plt.ylabel("calories")
plt.plot(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,90,86,84,83])
y=np.array([120,130,125,134,150])
plt.title("sport watch data")
plt.xlabel("average pulse")
plt.ylabel("calories")
plt.plot(x,y)
plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,90,86,84,83])
y=np.array([120,130,125,134,150])
plt.title("sport watch data")
plt.xlabel("average pulse")
plt.ylabel("calories")
#plt.plot(x,y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,90,86,84,83])
y=np.array([120,130,125,134,150])
plt.title("sport watch data")
plt.xlabel("average pulse")
plt.ylabel("calories")
plt.plot(x,y)
plt.grid(axis="y")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,90,86,84,83])
y=np.array([120,130,125,134,150])
plt.title("sport watch data")
plt.xlabel("average pulse")
plt.ylabel("calories")
plt.plot(x,y)
plt.grid(axis="x")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,90,86,84,83])
y=np.array([120,130,125,134,150])
plt.title("sport watch data")
plt.xlabel("average pulse")
plt.ylabel("calories")
plt.plot(x,y,color="green")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["apple","banana","cherry","durian"])
y=np.array([1,4,6,8])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["apple","banana","cherry","durian"])
y=np.array([1,4,6,8])
plt.barh(x,y,height=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["apple","banana","cherry","durian"])
y=np.array([1,4,6,8])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["apple","banana","cherry","durian"])
y=np.array([1,4,6,8])
#plt.bar(x,y,colors="gary","red","green","yellow")
plt.bar(x,y,width=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array(["apple","banana","cherry","durian"])
y=np.array([1,4,6,8])
#plt.bar(x,y,colors="gary","red","green","yellow")
plt.barh(x,y,height=0.5)
plt.show()

# %% [markdown]
# piechart

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,36,40,45])
plt.title
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,36,40,45])
plt.title
plt.pie(y,labels=["apple","banana","cherries","dates"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,36,40,45])
myexplode=[0.1,0,0,0]
plt.title

plt.pie(y,labels=["apple","banana","cherries","dates"],explode=myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,36,40,45])
myexplode=[0.1,0,0,0]
plt.title

plt.pie(y,labels=["apple","banana","cherries","dates"],explode=myexplode,shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,36,40,45])
myexplode=[0.1,0,0,0]
plt.title

plt.pie(y,labels=["apple","banana","cherries","dates"],explode=myexplode)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,36,40,45])
myexplode=[0.1,0,0,0]
plt.title
mycolors=["blue","red",]
plt.pie(y,labels=["apple","banana","cherries","dates"],explode=myexplode)
plt.show()

# %% [markdown]
# subplot

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,1)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,1)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,40,30])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(2,3,2)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([30,20,10,40])
plt.subplot(2,3,3)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,40,30])
plt.subplot(2,3,4)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([40,80,70,90])
plt.subplot(2,3,5)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,150,30])
plt.subplot(2,3,6)
plt.plot(x,y)


import numpy as np
x=np.array([0,1,2,3])
y=np.array([20,50,30,60])
plt.subplot(2,3,1)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,6,2)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([30,20,10,40])
plt.subplot(1,6,3)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,40,30])
plt.subplot(1,6,4)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([40,80,70,90])
plt.subplot(1,6,5)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,150,30])
plt.subplot(1,6,6)
plt.plot(x,y)


import numpy as np
x=np.array([0,1,2,3])
y=np.array([20,50,30,60])
plt.subplot(1,6,1)
plt.plot(x,y)
plt.show()

# %%
import numpy as np
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(6,1,2)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([30,20,10,40])
plt.subplot(6,1,3)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,40,30])
plt.subplot(6,1,4)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([40,80,70,90])
plt.subplot(6,1,5)
plt.plot(x,y)

import numpy as np
x=np.array([0,1,2,3])
y=np.array([110,80,150,30])
plt.subplot(6,1,6)
plt.plot(x,y)


import numpy as np
x=np.array([0,1,2,3])
y=np.array([20,50,30,60])
plt.subplot(6,1,1)
plt.plot(x,y)
plt.show()

# %%
#scatter
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
plt.scatter(x,y)
plt.show()

# %%
#two scatter
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
plt.scatter(x,y)

import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,115,120])
y=np.array([3,5,6,8,9,10,22,15,13])
plt.scatter(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
plt.scatter(x,y, color="r")

import numpy as np
import matplotlib.pyplot as plt
x=np.array([80,85,90,95,100,105,110,115,120])
y=np.array([3,5,6,8,9,10,22,15,13])
plt.scatter(x,y, color="g")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
colors=np.array(["red","green","yellow","blue","hotpink","black","pink","orange","gray"])
plt.scatter(x,y, c=colors)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
colors=np.array([0,10,20,30,40,50,60,70,80])
plt.scatter(x,y,c=colors,cmap="viridis")
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
colors=np.array([0,10,20,30,40,50,60,70,80])
size=np.array([20,30,400,440,500,600,700,800,900])
plt.scatter(x,y,c=colors,s=size)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([5,7,9,12,45,23,20,33,22])
y=np.array([80,85,90,95,100,105,110,115,120])
colors=np.array([0,10,20,30,40,50,60,70,80])
size=np.array([20,30,400,440,500,600,700,800,900])
plt.scatter(x,y,c=colors,s=size,alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))
sizes=10*np.random.randint(100,size=(100))
plt.scatter(x,y,c=colors,s=sizes,alpha=0.2,cmap="viridis")
plt.show()
